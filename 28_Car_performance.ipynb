# %%
# Car_performance

# %%
# import the basis libraries
import pandas as pd # dataframe creation
import numpy as np # linear algebra
import matplotlib.pyplot as plt# plot the image
# %matplotlib inline# good fit of image in the jupyter notebook space
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# Out:
# UsageError: unrecognized arguments: good fit of image in the jupyter notebook space

# %%
df = pd.read_csv("car_performance.csv")
df.head(100)
# Out:
#    origin  cylinders  model_year mpg_level car_company   mpg  displacement  \
# 0     usa          8          70    medium   chevrolet  18.0         307.0
# 1     usa          8          70       low       buick  15.0         350.0
# 2     usa          8          70    medium    plymouth  18.0         318.0
# 3     usa          8          70       low         amc  16.0         304.0
# 4     usa          8          70    medium        ford  17.0         302.0
# ..    ...        ...         ...       ...         ...   ...           ...
# 95    usa          8          73       low         amc  13.0         360.0
# 96    usa          6          73    medium    plymouth  18.0         225.0
# 97    usa          6          73       low   chevrolet  16.0         250.0
# 98    usa          6          73    medium         amc  18.0         232.0
# 99    usa          6          73    medium        ford  18.0         250.0
#
#     horsepower  weight  acceleration
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   origin        392 non-null    object
#  1   cylinders     392 non-null    int64
#  2   model_year    392 non-null    int64
#  3   mpg_level     392 non-null    object
#  4   car_company   392 non-null    object
#  5   mpg           392 non-null    float64
#  6   displacement  392 non-null    float64
#  7   horsepower    392 non-null    int64
#  8   weight        392 non-null    int64
#  9   acceleration  392 non-null    float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 30.8+ KB

# %%
df.describe()
# Out:
#         cylinders  model_year         mpg  displacement  horsepower  \
# count  392.000000  392.000000  392.000000    392.000000  392.000000
# mean     5.471939   75.979592   23.445918    194.411990  104.469388
# std      1.705783    3.683737    7.805007    104.644004   38.491160
# min      3.000000   70.000000    9.000000     68.000000   46.000000
# 25%      4.000000   73.000000   17.000000    105.000000   75.000000
# 50%      4.000000   76.000000   22.750000    151.000000   93.500000
# 75%      8.000000   79.000000   29.000000    275.750000  126.000000
# max      8.000000   82.000000   46.600000    455.000000  230.000000
#
#             weight  acceleration
# count   392.000000    392.000000
# mean   2977.584184     15.541327
# std     849.402560      2.758864
# min    1613.000000      8.000000
# 25%    2225.250000     13.775000
# 50%    2803.500000     15.500000
# 75%    3614.750000     17.025000
# max    5140.000000     24.800000

# %%
df.describe(include="O")
# Out:
#        origin mpg_level car_company
# count     392       392         392
# unique      3         3          37
# top       usa    medium        ford
# freq      245       205          48

# %%
# distribution of countries/origin

# %%
import seaborn as sns

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="origin",data=df)
plt.xlabel("Distribution of origin")
plt.title("Countries information")
# Out:
# Text(0.5, 1.0, 'Countries information')

# %%
# distribution about the cylinders

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="cylinders",data=df)
plt.xlabel("Distribution of cylinders")
plt.title("cylinders information")
# Out:
# Text(0.5, 1.0, 'cylinders information')

# %%
df.head()
# Out:
#   origin  cylinders  model_year mpg_level car_company   mpg  displacement  \
# 0    usa          8          70    medium   chevrolet  18.0         307.0
# 1    usa          8          70       low       buick  15.0         350.0
# 2    usa          8          70    medium    plymouth  18.0         318.0
# 3    usa          8          70       low         amc  16.0         304.0
# 4    usa          8          70    medium        ford  17.0         302.0
#
#    horsepower  weight  acceleration
# 0         130    3504          12.0
# 1         165    3693          11.5
# 2         150    3436          11.0
# 3         150    3433          12.0
# 4         140    3449          10.5

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="model_year",data=df)
plt.xlabel("Distribution of model_year")
plt.title("model_year information")
# Out:
# Text(0.5, 1.0, 'model_year information')

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="mpg",data=df)
plt.xlabel("Distribution of mpg")
plt.title("model_year information")
# Out:
# Text(0.5, 1.0, 'model_year information')

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="mpg_level",data=df)
plt.xlabel("Distribution of mpg_level")
plt.title("model_year information")
# Out:
# Text(0.5, 1.0, 'model_year information')

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="car_company",data=df)
plt.xlabel("Distribution of car_company")
plt.title("model_year information")
# Out:
# Text(0.5, 1.0, 'model_year information')

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="displacement",data=df)
plt.xlabel("Distribution of model_year")
plt.title("model_year information")
# Out:
# Text(0.5, 1.0, 'model_year information')

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="horsepower",data=df)
plt.xlabel("Distribution of model_year")
plt.title("model_year information")
# Out:
# Text(0.5, 1.0, 'model_year information')

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="weight",data=df)
plt.xlabel("Distribution of model_year")
plt.title("model_year information")
# Out:
# Text(0.5, 1.0, 'model_year information')

# %%
plt.figure(figsize=(7,7))
sns.countplot(x="acceleration",data=df)
plt.xlabel("Distribution of model_year")
plt.title("model_year information")
# Out:
# Text(0.5, 1.0, 'model_year information')

# %%
# subplot

# %%
plt.subplots(2,2,figsize=(16,10))

plt.subplot(2,2,1)
sns.countplot(x="origin", data=df)
plt.xlabel("Distribution of origin")
plt.title("Countries information")

plt.subplot(2,2,2)
sns.countplot(x="cylinders",data=df)
plt.xlabel("Distribution of cylinders")
plt.title("cylinders information")
# Out:
# Text(0.5, 1.0, 'cylinders information')

# %%
plt.subplot(2,2,3)
sns.countplot(x="model_year",data=df)
plt.xlabel("Distribution of cly")
plt.title("cly information")

plt.subplot(2,2,4)
sns.countplot(x="mpg_level",data=df)
plt.xlabel("Distribution of cly")
plt.title("cly information")
# Out:
# Text(0.5, 1.0, 'cly information')

# %%
plt.subplots(2,2,figsize=(16,10))

plt.subplot(2,2,1)
sns.countplot(x="origin",data=df)
plt.xlabel("Distribution of origin")
plt.title("Countries information")


plt.subplot(2,2,2)
sns.countplot(x="cylinders",data=df)
plt.xlabel("Distribution of cly")
plt.title("cly information")

plt.subplot(2,2,3)
sns.countplot(x="model_year",data=df)
plt.xlabel("Distribution of cly")
plt.title("cly information")

plt.subplot(2,2,4)
sns.countplot(x="mpg_level",data=df)
plt.xlabel("Distribution of cly")
plt.title("cly information")
# Out:
# Text(0.5, 1.0, 'cly information')

# %%
# pie plot
plt.figure(figsize=(8,8))
plt.pie(x=df["origin"].value_counts(), autopct="%0.2f%%",data=df)
# Out:
# ([<matplotlib.patches.Wedge at 0x226f62297d0>,
# ...
#  [Text(-0.42095177560159874, 1.0162674857624154, ''),
#   Text(-0.16685167040745827, -1.0872720543094267, ''),
#   Text(0.9406570273206045, -0.570231844912544, '')],
#  [Text(-0.22961005941905382, 0.5543277195067721, '62.50%'),
#   Text(-0.09101000204043178, -0.5930574841687782, '20.15%'),
#   Text(0.5130856512657842, -0.31103555177047854, '17.35%')])

# %%
df["origin"].value_counts()
# Out:
# usa       245
# japan      79
# europe     68
# Name: origin, dtype: int64

# %%
# pie plot
plt.figure(figsize=(8,8))
plt.pie(x=df["origin"].value_counts(),labels=df["origin"].value_counts().index,autopct="%0.2f%%",data=df)
# Out:
# ([<matplotlib.patches.Wedge at 0x226f6b546d0>,
# ...
#  [Text(-0.42095177560159874, 1.0162674857624154, 'usa'),
#   Text(-0.16685167040745827, -1.0872720543094267, 'japan'),
#   Text(0.9406570273206045, -0.570231844912544, 'europe')],
#  [Text(-0.22961005941905382, 0.5543277195067721, '62.50%'),
#   Text(-0.09101000204043178, -0.5930574841687782, '20.15%'),
#   Text(0.5130856512657842, -0.31103555177047854, '17.35%')])

# %%
#pie plot
plt.figure(figsize=(8,8))
plt.pie(x=df["origin"].value_counts(),labels=df["origin"].value_counts().index,data=df)
# Out:
# ([<matplotlib.patches.Wedge at 0x226f6bc46d0>,
# ...
#  [Text(-0.42095177560159874, 1.0162674857624154, 'usa'),
#   Text(-0.16685167040745827, -1.0872720543094267, 'japan'),
#   Text(0.9406570273206045, -0.570231844912544, 'europe')])

# %%
plt.subplots(2,2,figsize=(16,10))

plt.subplot(2,2,1)
plt.pie(x=df["origin"].value_counts(),labels=df["origin"].value_counts().index,autopct='%0.2f%%',data=df)
plt.title('Percentage of each origin in the data')

plt.subplot(2,2,2)
plt.title("Distribution of cylinder")
plt.pie(x=df["cylinders"].value_counts(),labels=df["cylinders"].value_counts().index,autopct='%0.2f%%',explode=[0,0,0,0.03,0.2],data=df)


plt.subplot(2,2,3)

plt.title("Distribution of model_year")
plt.pie(x=df["model_year"].value_counts(),labels=df["model_year"].value_counts().index,autopct='%0.2f%%',data=df)

plt.subplot(2,2,4)
plt.title("Distribution of mpg_level")
plt.pie(x=df["mpg_level"].value_counts(),labels=df["mpg_level"].value_counts().index,autopct='%0.2f%%',data=df)

plt.show()

# %%
"""
USA country has the largest contribution 62.505
4-cylinder contributes 50.77%
1973 year alone has a contribution of 10.2%
"Meedium" mileage car contribution is 52.3%
"""
# Out:
# '\nUSA country has the largest contribution 62.505\n4-cylinder contributes 50.77%\n1973 year alone has a contribution of 10.2%\n"Meedium" mileage car contribution is 52.3%\n'

# %%
# cylinder w.r. to country

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="cylinders",data=df,hue="origin")
plt.title("Distribution of cylinders bifurgation with r.to country")
plt.show()

# %%
# Cylinders as per origin

""" 
Japan is the only origin with 3 cylinders
europe .. 5 cylinder
use ....8 cylinder 

all countries has 4 cylinder
all countries has 6 cylinder but dominated by USA

"""
# Out:
# ' \nJapan is the only origin with 3 cylinders\neurope .. 5 cylinder\nuse ....8 cylinder \n\nall countries has 4 cylinder\nall countries has 6 cylinder but dominated by USA\n\n'

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="mpg_level", data=df, hue="origin")
plt.title("Distribution of mpg_level bifurgation with r.to country")
plt.show()

# %%
"""
Japan doesn't have any vechile with low_mpg level
where europe has negligible car with low mpg_level 

"""
# Out:
# "\nJapan doesn't have any vechile with low_mpg level\nwhere europe has negligible car with low mpg_level \n\n"

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="mpg_level",data=df,hue="cylinders")
plt.title("Distribution of mpg_level bifurgation with respect to  no. of cylinders")
plt.show()

# %% [markdown]
# Car with low mileage has either 6 or 8 cylinders most of car high mileage has 4 cylinder

# %%
# Catplot

# %%
sns.catplot(x="mpg_level", hue="cylinders",col="origin",data=df,kind="count")
plt.show()

# %%
# Please write your observations

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="model_year",data=df,hue="cylinders")
# Out:
# <Axes: xlabel='model_year', ylabel='count'>

# %%
"""
These results make sense as with the devlopment of technology high mileage with low cylinders.
"""
# Out:
# '\nThese results make sense as with the devlopment of technology high mileage with low cylinders.\n'

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="model_year",data=df, hue="origin")
# Out:
# <Axes: xlabel='model_year', ylabel='count'>

# %%
"""
As the year process japan and europe started manufacturing more vehicles.
"""
# Out:
# '\nAs the year process japan and europe started manufacturing more vehicles.\n'

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="car_company",data=df)
# Out:
# <Axes: xlabel='car_company', ylabel='count'>

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="car_company",data=df)
plt.xticks(rotation=75)
plt.xlabel("distribution of car_company")
# Out:
# Text(0.5, 0, 'distribution of car_company')

# %%
df["car_company"].value_counts()
# Out:
# ford             48
# chevrolet        43
# plymouth         31
# dodge            28
# amc              27
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# mazda            10
# oldsmobile       10
# fiat              8
# peugeot           8
# audi              7
# vw                6
# chrysler          6
# volvo             6
# opel              4
# saab              4
# subaru            4
# chevy             3
# renault           3
# maxda             2
# cadillac          2
# bmw               2
# mercedes-benz     2
# triumph           1
# vokswagen         1
# mercedes          1
# hi                1
# capri             1
# chevroelt         1
# toyouta           1
# nissan            1
# Name: car_company, dtype: int64

# %%
plt.figure(figsize=(18,8))
sns.countplot(x="car_company",data=df,order=df["car_company"].value_counts().index)
plt.xticks(rotation=75)
plt.xlabel("distribution of car_company")
# Out:
# Text(0.5, 0, 'distribution of car_company')

# %%
df["car_company"].value_counts(normalize=True)
# Out:
# ford             0.122449
# chevrolet        0.109694
# plymouth         0.079082
# dodge            0.071429
# amc              0.068878
# toyota           0.063776
# datsun           0.058673
# buick            0.043367
# pontiac          0.040816
# volkswagen       0.038265
# honda            0.033163
# mercury          0.028061
# mazda            0.025510
# oldsmobile       0.025510
# fiat             0.020408
# peugeot          0.020408
# audi             0.017857
# vw               0.015306
# chrysler         0.015306
# volvo            0.015306
# opel             0.010204
# saab             0.010204
# subaru           0.010204
# chevy            0.007653
# renault          0.007653
# maxda            0.005102
# cadillac         0.005102
# bmw              0.005102
# mercedes-benz    0.005102
# triumph          0.002551
# vokswagen        0.002551
# mercedes         0.002551
# hi               0.002551
# capri            0.002551
# chevroelt        0.002551
# ...

# %% [markdown]
# # Bar plot

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="origin",y="displacement",data=df)
# Out:
# <Axes: xlabel='origin', ylabel='displacement'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="origin",y="mpg",data=df)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="origin",data=df)
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="origin",y="mpg",data=df,hue="cylinders")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="origin",y="mpg",data=df,hue="car_company")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="origin",y="mpg",data=df,hue="displacement")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="origin",y="mpg",data=df,hue="horsepower")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="origin",y="mpg",data=df,hue="weight")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="origin",y="mpg",data=df,hue="acceleration")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="cylinders",y="mpg_level",data=df,hue="car_company")
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg_level'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="cylinders",y="mpg_level",data=df,hue="horsepower")
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg_level'>

# %%
# Subplots with barplot PLEASE TRY URSELF AND WRITE YOUR OBSERVATION

# %% [markdown]
# # LINEPLOT

# %%
plt.subplots(2,3,figsize=(16,10))

plt.subplot(2,3,1)
sns.lineplot(x="model_year",y="mpg",hue="origin",data=df,err_style="bars")
plt.xlabel("model year")

plt.subplot(2,3,2)
sns.lineplot(x="model_year",y="displacement",hue="origin",data=df,err_style="bars")
plt.xlabel("model year")

plt.subplot(2,3,3)
sns.lineplot(x="model_year",y="horsepower",hue="origin",data=df,err_style="bars")
plt.xlabel("model year")

plt.subplot(2,3,4)
sns.lineplot(x="model_year",y="weight",hue="origin",data=df)
plt.xlabel("model year")

plt.subplot(2,3,5)
sns.lineplot(x="model_year",y="acceleration",hue="origin",data=df)
plt.xlabel("model year")
# Out:
# Text(0.5, 0, 'model year')

# %%
plt.subplots(2,3,figsize=(16,10))

plt.subplot(2,3,1)
sns.lineplot(x="model_year",y="mpg",hue="origin",data=df,err_style="bars")
plt.xlabel("model year")

plt.subplot(2,3,2)
sns.lineplot(x="model_year",y="displacement",hue="origin",data=df,err_style="bars")
plt.xlabel("model year")

plt.subplot(2,3,3)
sns.lineplot(x="model_year",y="horsepower",hue="origin",data=df,err_style="bars")
plt.xlabel("model year")

plt.subplot(2,3,4)
sns.lineplot(x="model_year",y="weight",hue="origin",data=df)
plt.xlabel("model year")

plt.subplot(2,3,5)
sns.lineplot(x="model_year",y="acceleration",hue="origin",data=df)
plt.xlabel("model year")

plt.subplot(2,3,6)
sns.lineplot(x="model_year",y="car_company",hue="origin",data=df)
# Out:
# <Axes: xlabel='model_year', ylabel='car_company'>

# %%
#please write your comments

# %% [markdown]
# # HISTOGRAM

# %%
# it is very useful to see if the data is following the normal distribution or not

# %%
plt.figure(figsize=(8,6))
sns.histplot(x="mpg",data=df)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(x="mpg",data=df,kde=True)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(x="mpg",data=df,kde=True,stat="probability")
# Out:
# <Axes: xlabel='mpg', ylabel='Probability'>

# %%
# please try with all numerical variable and comments

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(df["mpg"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["displacement"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["acceleration"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["horsepower"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["horsepower"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["model_year"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["weight"])
# Out:
# <Axes: >

# %%
df1=df.drop(["origin","mpg_level","car_company"],axis=1)

# %%
df1.head()
# Out:
#    cylinders  model_year   mpg  displacement  horsepower  weight  acceleration
# 0          8          70  18.0         307.0         130    3504          12.0
# 1          8          70  15.0         350.0         165    3693          11.5
# 2          8          70  18.0         318.0         150    3436          11.0
# 3          8          70  16.0         304.0         150    3433          12.0
# 4          8          70  17.0         302.0         140    3449          10.5

# %%
sns.boxplot(data=df1)
# Out:
# <Axes: >

# %%
sns.pairplot(data=df1)

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   origin  cylinders  model_year mpg_level car_company   mpg  displacement  \
# 0    usa          8          70    medium   chevrolet  18.0         307.0
# 1    usa          8          70       low       buick  15.0         350.0
# 2    usa          8          70    medium    plymouth  18.0         318.0
# 3    usa          8          70       low         amc  16.0         304.0
# 4    usa          8          70    medium        ford  17.0         302.0
#
#    horsepower  weight  acceleration
# 0         130    3504          12.0
# 1         165    3693          11.5
# 2         150    3436          11.0
# 3         150    3433          12.0
# 4         140    3449          10.5
